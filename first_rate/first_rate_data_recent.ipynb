# %%
import requests
from zipfile import ZipFile
from urllib.request import urlretrieve
from boto3.session import Session
import boto3
import io
import os
from io import StringIO
import botocore
import pandas as pd
import numpy as np
from datetime import datetime
from pytz import timezone
import pytz
import os
import pyodbc
import struct
import datetime
import matplotlib.pyplot as plt
import scipy.stats as stats
from functools import reduce
from dotenv import load_dotenv
from functools import reduce
load_dotenv()
pd.options.mode.chained_assignment = None

# %%
def get_s3_object(bucket,folder,fileName):
    s3 = boto3.client('s3')
    key = folder+fileName
    obj = s3.get_object(Bucket=bucket, Key=key)
    df = pd.read_csv(obj['Body'],index_col=0)
    print(f'Downloaded: {bucket}:{key}')
    return df

# %%
#takes raw data from FRD in s3 and converts it into bar format
def get_formatted_future(bucket,folder,fileName):
    s3 = boto3.client('s3')
    key = folder+fileName
    obj = s3.get_object(Bucket=bucket, Key=key)
    df = pd.read_csv(obj['Body'],names=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
    df = df.set_index('Date')
    df.index = pd.to_datetime(df.index)
    df.index = df.index.tz_localize('US/Eastern')
    df.index = df.index.strftime('%Y-%m-%d %H:%M:%S %z').str[:-2] + ':00'
    df['Engine'] = None
    df['Source'] = 'FirstRateData'
    df['Update'] = get_pst_time()
    return df

# %%
def check_if_s3_object_exists(bucket, folder,fileName):
    s3 = boto3.resource('s3')
    try:
        s3.Object(bucket, folder+fileName).load()
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            # The object does not exist.
            return False
        else:
            # Something else has gone wrong.
            raise
    else:
        return True

# %%
def get_pst_time():
    date_format='%Y-%m-%d %H:%M:%S %z'
    date = datetime.datetime.now(tz=pytz.utc)
    date = date.astimezone(timezone('US/Pacific'))
    pstDateTime=date.strftime(date_format)
    pstDateTime = "{0}:{1}".format(pstDateTime[:-2],pstDateTime[-2:])
    return pstDateTime

# %%
def save_s3_object(bucket,folder,filename,datafrane):
    csv_buffer = StringIO()
    datafrane.to_csv(csv_buffer, sep=",", index=True)
    s3_resource = boto3.resource('s3')
    s3_resource.Object(bucket, folder+filename).put(Body=csv_buffer.getvalue())   
    print(f'Saved S3 Object: {bucket}:{folder}{filename}')

# %%
def update_2_hour(df, df2):
    df_slice = df.loc[df.index >= df2.index[-2]]
    df_format = get_2_hour(df_slice)
    return pd.concat([df2.iloc[:-2], df_format])

def get_2_hour(df_origin):
    df_ret = pd.DataFrame()
    counter = 0
    #turns every 2 rows into a row, except when there is only one row left
    while not df_origin.empty:
        if df_origin.shape[0] == 1:
            df_ret = df_ret.append(df_origin, ignore_index=True)
            df_ret.loc[df_ret.index[-1], 'Date'] = df_origin.index
            print(f'{counter} frames added')
            break
        else:
            df = df_origin.iloc[:2]
            new_row = {'Date':df.index[0],'Open':df['Open'][0],'High':df['High'].max(),'Low':df['Low'].min(),'Close':df['Close'][1],'Volume':df['Volume'].sum()}
            df_ret = df_ret.append(new_row, ignore_index=True)
            df_origin = df_origin.iloc[2:, :]
            counter += 1
            if counter % 10000 == 0:
                print(f'{counter} frames added')
    df_ret['Engine'] = 'Internal'
    df_ret['Source'] = 'FirstRateData'
    df_ret['Update'] = get_pst_time()
    return df_ret.set_index('Date')

# %%
#Daily bar consists of previous data from 18:00 from previous day -> 16:00 of next day
#this function takes the hourly data from FRD and converts it into daily data
def get_daily_bars(df):
    df_return = pd.DataFrame(columns=['Date','Open','High','Low','Close','Volume','Engine','Source','Update'])
    df = df.reset_index()
    datetime = df['Date'].str.split(" ", expand = True)
    df['Date'] = datetime[0]
    df['Time'] = datetime[1]
    df['Offset'] = datetime[2]
    #day for futures starts at 18:00:00, ends at 16:00:00
    df = df[df['Time'] != '17:00:00']
    df = df.reset_index(drop=True)
    prev, today, last_date = get_day(df)
    df_return = df_return.append(today, ignore_index=True)
    df_new = df.iloc[last_date+1:]
    while not df_new.empty:
        prev2, today2, last_date = get_day(df_new)
        if prev is None and today2 is not None:
            df_return = df_return.append(today2, ignore_index=True)
        elif today2 is None and prev is not None:
            df_return = df_return.append(prev, ignore_index=True)
        elif prev is not None and today2 is not None:
            new_row = concat_prev_today(prev,today2)
            df_return = df_return.append(new_row, ignore_index=True)
        prev = prev2
        df_new = df.iloc[last_date+1:]
    df_return['Engine'] = 'Internal'
    df_return['Source'] = 'FirstRateData'
    df_return['Update'] = get_pst_time()
    return df_return.set_index('Date')

def get_day(df):
    date = df.iloc[0]['Date']
    df_slice = df[df['Date'] == date]
    df_prev = df_slice[df_slice['Time'] > '17:00:00']
    df_today = df_slice[df_slice['Time'] < '17:00:00']
    prev = None
    today = None

    if not df_prev.empty:
        prev = format_df(df_prev)
    if not df_today.empty:    
        today = format_df(df_today)
    return prev, today, df_slice.index[-1]

# %%
#concats dataframe of rows and returns it as one row
def format_df(df):
    open_df = df['Open'].iloc[0]
    high_df = df['High'].max()
    low_df = df['Low'].min()
    close_df = df['Close'].iloc[-1]
    volume_df = df['Volume'].sum()
    date_df = df['Date'].iloc[0] + ' ' + df['Time'].iloc[0] + ' ' + df['Offset'].iloc[0]
    new_row = {'Date':date_df,'Open':open_df,'High':high_df,'Low':low_df,'Close':close_df,'Volume':volume_df}
    return new_row

# %%
#gets previous day's bar and next day's bar and concats it into one bar
def concat_prev_today(prev, today):
    new_row = {'Date':prev['Date'],'Open':prev['Open'],'High':max(prev['High'], today['High']),'Low':min(prev['Low'],today['Low']),'Close':today['Close'],'Volume':prev['Volume']+today['Volume'] }
    return new_row

# %% [markdown]
# Database Connection

# %%
server = 'prod.db.liminalcap.com'
database = 'LCData'
username = 'acameron'
password = 'dougal88'
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

# %%
#dict that stores differences between database code and FRD code
code_dict = {
    'A6': 'AD', 'AD': 'CD','B6': 'BP', 'BTP': 'IK','BZ': 'BZA',
    'CA': 'CC','DY': 'GX','E1': 'SF','E6': 'EC','EW': 'FA',
    'FX': 'VG','GF': 'FC','GG': 'RX','HE': 'LH','HR': 'OE',
    'J1': 'JY','LBS': 'LB','LE': 'LC','MES': 'HWA','MME': 'MES',
    'MNQ': 'HWB','MP': 'ME','MX': 'CF','N6': 'NV','RB': 'XB',
    'TN': 'ZT','VX': 'UX','YM': 'DM','ZC': 'C','ZF': 'TU',
    'ZL': 'BO','ZM': 'SM','ZN': 'TY','ZO': 'O','ZQ': 'FF',
    'ZR': 'RR','ZS': 'S','ZT': 'TU','ZW': 'W',
}

# %%
#gets raw files that are stored in s3 from FRD, then converts into bar format and stores back into s3

bucket = 'lc-tempstorage'
prefix = 'onemin/onemin/'
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucket)

for obj in my_bucket.objects.filter(Prefix=prefix):
    filename = obj.key.split('/')[2]
    #df = get_formatted_future(bucket, prefix, filename)
    
    code = filename.split('_')[0]
    code_format = code_dict.get(code, code)
    #print(f'{code} : {code_format}')
    cursor.execute("SELECT [MinuteRecordId] FROM dbo.FuturesStubs WHERE BBSymbol = ? AND TTSymbol IS NOT NULL", code_format)
    for row in cursor.fetchall():
        cursor.execute("SELECT [S3BucketName], [S3PathName], [S3FileName] FROM dbo.DataRecords WHERE Id = ?", row[0])
        for row_nest in cursor.fetchall():
            if cursor.rowcount != 0:
                df = get_formatted_future(bucket, prefix, filename)
                save_s3_object(row_nest[0], row_nest[1], 'FRD_'+row_nest[2], df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7984/291599770.py in <module>
#      19             if cursor.rowcount != 0:
#      20                 df = get_formatted_future(bucket, prefix, filename)
# ---> 21                 save_s3_object(row_nest[0], row_nest[1], 'FRD_'+row_nest[2], df)
#
# ~\AppData\Local\Temp/ipykernel_7984/3617892072.py in save_s3_object(bucket, folder, filename, datafrane)
#       3     datafrane.to_csv(csv_buffer, sep=",", index=True)
#       4     s3_resource = boto3.resource('s3')
# ----> 5     s3_resource.Object(bucket, folder+filename).put(Body=csv_buffer.getvalue())
#       6     print(f'Saved S3 Object: {bucket}:{folder}{filename}')
#
# ~\anaconda3\lib\site-packages\boto3\resources\factory.py in do_action(self, *args, **kwargs)
#     578             # instance via ``self``.
#     579             def do_action(self, *args, **kwargs):
# --> 580                 response = action(self, *args, **kwargs)
#     581
#     582                 if hasattr(self, 'load'):
#
# ~\anaconda3\lib\site-packages\boto3\resources\action.py in __call__(self, parent, *args, **kwargs)
#      86         )
#      87
# ---> 88         response = getattr(parent.meta.client, operation_name)(*args, **params)
#      89
#      90         logger.debug('Response: %r', response)
#
# ~\anaconda3\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     399                     "%s() only accepts keyword arguments." % py_operation_name)
#     400             # The "self" in this scope is referring to the BaseClient.
# --> 401             return self._make_api_call(operation_name, kwargs)
#     402
#     403         _api_call.__name__ = str(py_operation_name)
#
# ~\anaconda3\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     715         else:
#     716             apply_request_checksum(request_dict)
# --> 717             http, parsed_response = self._make_request(
#     718                 operation_model, request_dict, request_context)
#     719
#
# ~\anaconda3\lib\site-packages\botocore\client.py in _make_request(self, operation_model, request_dict, request_context)
#     735     def _make_request(self, operation_model, request_dict, request_context):
#     736         try:
# --> 737             return self._endpoint.make_request(operation_model, request_dict)
#     738         except Exception as e:
#     739             self.meta.events.emit(
#
# ~\anaconda3\lib\site-packages\botocore\endpoint.py in make_request(self, operation_model, request_dict)
#     105         logger.debug("Making request for %s with params: %s",
#     106                      operation_model, request_dict)
# --> 107         return self._send_request(request_dict, operation_model)
#     108
#     109     def create_request(self, params, operation_model=None):
#
# ~\anaconda3\lib\site-packages\botocore\endpoint.py in _send_request(self, request_dict, operation_model)
#     179         self._update_retries_context(context, attempts)
#     180         request = self.create_request(request_dict, operation_model)
# --> 181         success_response, exception = self._get_response(
#     182             request, operation_model, context)
#     183         while self._needs_retry(attempts, operation_model, request_dict,
#
# ~\anaconda3\lib\site-packages\botocore\endpoint.py in _get_response(self, request, operation_model, context)
#     213         # If an exception occurs then the success_response is None.
#     214         # If no exception occurs then exception is None.
# --> 215         success_response, exception = self._do_get_response(
#     216             request, operation_model, context)
#     217         kwargs_to_emit = {
#
# ~\anaconda3\lib\site-packages\botocore\endpoint.py in _do_get_response(self, request, operation_model, context)
#     247             http_response = first_non_none_response(responses)
#     248             if http_response is None:
# --> 249                 http_response = self._send(request)
#     250         except HTTPClientError as e:
#     251             return (None, e)
#
# ~\anaconda3\lib\site-packages\botocore\endpoint.py in _send(self, request)
#     319
#     320     def _send(self, request):
# --> 321         return self.http_session.send(request)
#     322
#     323
#
# ~\anaconda3\lib\site-packages\botocore\httpsession.py in send(self, request)
#     414
#     415             request_target = self._get_request_target(request.url, proxy_url)
# --> 416             urllib_response = conn.urlopen(
#     417                 method=request.method,
#     418                 url=request_target,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                 conn.request_chunked(method, url, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#     396         # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     237         if "user-agent" not in (six.ensure_str(k.lower()) for k in headers):
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#     241     def request_chunked(self, method, url, body=None, headers=None):
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1277                 encode_chunked=False):
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#    1281     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\anaconda3\lib\site-packages\botocore\awsrequest.py in _send_request(self, method, url, body, headers, *args, **kwargs)
#      91             self._expect_header_set = False
#      92             self.response_class = self._original_response_cls
# ---> 93         rval = super(AWSConnection, self)._send_request(
#      94             method, url, body, headers, *args, **kwargs)
#      95         self._expect_header_set = False
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1323             # default charset of iso-8859-1.
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#    1327     def getresponse(self):
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1272         else:
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#    1276     def request(self, method, url, body=None, headers={}, *,
#
# ~\anaconda3\lib\site-packages\botocore\awsrequest.py in _send_output(self, message_body, *args, **kwargs)
#     126             # Wait for 1 second for the server to send a response.
#     127             if urllib3.util.wait_for_read(self.sock, 1):
# --> 128                 self._handle_expect_response(message_body)
#     129                 return
#     130             else:
#
# ~\anaconda3\lib\site-packages\botocore\awsrequest.py in _handle_expect_response(self, message_body)
#     169                 logger.debug("100 Continue response seen, "
#     170                              "now sending request body.")
# --> 171                 self._send_message_body(message_body)
#     172             elif len(parts) == 3 and parts[0].startswith(b'HTTP/'):
#     173                 # From the RFC:
#
# ~\anaconda3\lib\site-packages\botocore\awsrequest.py in _send_message_body(self, message_body)
#     196     def _send_message_body(self, message_body):
#     197         if message_body is not None:
# --> 198             self.send(message_body)
#     199
#     200     def send(self, str):
#
# ~\anaconda3\lib\site-packages\botocore\awsrequest.py in send(self, str)
#     203                          "Not sending data.")
#     204             return
# --> 205         return super(AWSConnection, self).send(str)
#     206
#     207     def _is_100_continue_status(self, maybe_status_line):
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     990                 if encode:
#     991                     datablock = datablock.encode("iso-8859-1")
# --> 992                 self.sock.sendall(datablock)
#     993             return
#     994         try:
#
# ~\anaconda3\lib\ssl.py in sendall(self, data, flags)
#    1202                 amount = len(byte_view)
#    1203                 while count < amount:
# -> 1204                     v = self.send(byte_view[count:])
#    1205                     count += v
#    1206         else:
#
# ~\anaconda3\lib\ssl.py in send(self, data, flags)
#    1171                     "non-zero flags not allowed in calls to send() on %s" %
#    1172                     self.__class__)
# -> 1173             return self._sslobj.write(data)
#    1174         else:
#    1175             return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
cursor.execute("SELECT [HourRecordId] FROM dbo.FuturesStubs WHERE TTSymbol IS NOT NULL")
for row in cursor.fetchall():
    cursor.execute("SELECT [S3BucketName], [S3PathName], [S3FileName] FROM dbo.DataRecords WHERE Id = ?", row[0])
    for row_nest in cursor.fetchall():
        twohour = 'FRD_'+row_nest[2].replace('hour', '2hour')
        if check_if_s3_object_exists(row_nest[0], row_nest[1], twohour):
            df = get_s3_object(row_nest[0], row_nest[1], twohour)
            df = df[['Open', 'High', 'Low', 'Close', 'Engine', 'Source', 'Update']]
            save_s3_object(row_nest[0], row_nest[1], twohour, df)
# Out:
# Downloaded: lc-market-data:Futures/US/CME/ES/FRD_ESC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/ES/FRD_ESC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/NQ/FRD_NQC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/NQ/FRD_NQC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/DM/FRD_DMC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/DM/FRD_DMC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/FA/FRD_FAC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/FA/FRD_FAC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/RTY/FRD_RTYC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/RTY/FRD_RTYC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/CL/FRD_CLC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/CL/FRD_CLC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/NG/FRD_NGC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/NG/FRD_NGC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/XB/FRD_XBC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/XB/FRD_XBC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/HO/FRD_HOC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/HO/FRD_HOC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/FF/FRD_FFC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/FF/FRD_FFC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/ED/FRD_EDC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/ED/FRD_EDC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/TU/FRD_TUC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/TU/FRD_TUC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/TY/FRD_TYC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/TY/FRD_TYC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/US/FRD_USC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/US/FRD_USC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CMX/GC/FRD_GCC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CMX/GC/FRD_GCC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CMX/HG/FRD_HGC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CMX/HG/FRD_HGC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CMX/SI/FRD_SIC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CMX/SI/FRD_SIC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/PL/FRD_PLC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/PL/FRD_PLC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/PA/FRD_PAC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/PA/FRD_PAC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/GX/FRD_GXC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/GX/FRD_GXC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/VG/FRD_VGC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/VG/FRD_VGC1_2hour.txt
# Downloaded: lc-market-data:Futures/FR/EOP/CF/FRD_CFC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/FR/EOP/CF/FRD_CFC1_2hour.txt
# Downloaded: lc-market-data:Futures/NZ/SFE/ZT/FRD_ZTC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/NZ/SFE/ZT/FRD_ZTC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/OE/FRD_OEC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/OE/FRD_OEC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/RX/FRD_RXC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/RX/FRD_RXC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/EC/FRD_ECC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/EC/FRD_ECC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/JY/FRD_JYC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/JY/FRD_JYC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/BP/FRD_BPC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/BP/FRD_BPC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/AD/FRD_ADC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/AD/FRD_ADC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/CD/FRD_CDC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/CD/FRD_CDC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/SF/FRD_SFC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/SF/FRD_SFC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/NV/FRD_NVC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/NV/FRD_NVC1_2hour.txt
# Downloaded: lc-market-data:Futures/GB/ICF/L /FRD_L C1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/GB/ICF/L /FRD_L C1_2hour.txt
# Downloaded: lc-market-data:Futures/GB/ICF/G /FRD_G C1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/GB/ICF/G /FRD_G C1_2hour.txt
# Downloaded: lc-market-data:Futures/GB/ICF/ES/FRD_ESC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/GB/ICF/ES/FRD_ESC1_2hour.txt
# Downloaded: lc-market-data:Futures/CH/EUX/SM/FRD_SMC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/CH/EUX/SM/FRD_SMC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBF/UX/FRD_UXC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBF/UX/FRD_UXC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYF/MES/FRD_MESC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYF/MES/FRD_MESC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/BTC/FRD_BTCC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/BTC/FRD_BTCC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/FNX/DX/FRD_DXC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/FNX/DX/FRD_DXC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/C /FRD_C C1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/C /FRD_C C1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME//FRD_C1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME//FRD_C1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME//FRD_C1_2hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME//FRD_C1_2hour.txt

# %%
cursor.execute("SELECT [HourRecordId] FROM dbo.FuturesStubs WHERE TTSymbol IS NOT NULL")
for row in cursor.fetchall():
    cursor.execute("SELECT [S3BucketName], [S3PathName], [S3FileName] FROM dbo.DataRecords WHERE Id = ?", row[0])
    for row_nest in cursor.fetchall():
        twohour = 'FRD_'+row_nest[2].replace('hour', '2hour')
        if check_if_s3_object_exists(row_nest[0], row_nest[1], 'FRD_'+row_nest[2]):
            df = get_s3_object(row_nest[0], row_nest[1], 'FRD_'+row_nest[2])
            df_2hour = get_2_hour(df)
            df_2hour = df_2hour[['Open', 'High', 'Low', 'Close', 'Volume', 'Engine', 'Source', 'Update']]
            save_s3_object(row_nest[0], row_nest[1], twohour, df_2hour)
# Out:
# Downloaded: lc-market-data:Futures/US/CME/ES/FRD_ESC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 48543 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/ES/FRD_ESC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/NQ/FRD_NQC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 46628 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/NQ/FRD_NQC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/DM/FRD_DMC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 46105 frames added
# Saved S3 Object: lc-market-data:Futures/US/CBT/DM/FRD_DMC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/FA/FRD_FAC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 39384 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/FA/FRD_FAC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/RTY/FRD_RTYC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/RTY/FRD_RTYC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/CL/FRD_CLC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# Saved S3 Object: lc-market-data:Futures/US/NYM/CL/FRD_CLC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/NG/FRD_NGC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 44367 frames added
# Saved S3 Object: lc-market-data:Futures/US/NYM/NG/FRD_NGC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/XB/FRD_XBC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 42195 frames added
# Saved S3 Object: lc-market-data:Futures/US/NYM/XB/FRD_XBC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/HO/FRD_HOC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# Saved S3 Object: lc-market-data:Futures/US/NYM/HO/FRD_HOC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/FF/FRD_FFC1_hour.txt
# 10000 frames added
# 16985 frames added
# Saved S3 Object: lc-market-data:Futures/US/CBT/FF/FRD_FFC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/ED/FRD_EDC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 40283 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/ED/FRD_EDC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/TU/FRD_TUC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CBT/TU/FRD_TUC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/TY/FRD_TYC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 45137 frames added
# Saved S3 Object: lc-market-data:Futures/US/CBT/TY/FRD_TYC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBT/US/FRD_USC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 45253 frames added
# Saved S3 Object: lc-market-data:Futures/US/CBT/US/FRD_USC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CMX/GC/FRD_GCC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 41673 frames added
# Saved S3 Object: lc-market-data:Futures/US/CMX/GC/FRD_GCC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CMX/HG/FRD_HGC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 42371 frames added
# Saved S3 Object: lc-market-data:Futures/US/CMX/HG/FRD_HGC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CMX/SI/FRD_SIC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CMX/SI/FRD_SIC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/PL/FRD_PLC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 41104 frames added
# Saved S3 Object: lc-market-data:Futures/US/NYM/PL/FRD_PLC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYM/PA/FRD_PAC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 40037 frames added
# Saved S3 Object: lc-market-data:Futures/US/NYM/PA/FRD_PAC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/GX/FRD_GXC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 31847 frames added
# Saved S3 Object: lc-market-data:Futures/DE/EUX/GX/FRD_GXC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/VG/FRD_VGC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 31951 frames added
# Saved S3 Object: lc-market-data:Futures/DE/EUX/VG/FRD_VGC1_2hour.txt
# Downloaded: lc-market-data:Futures/FR/EOP/CF/FRD_CFC1_hour.txt
# 10000 frames added
# 20000 frames added
# 27052 frames added
# Saved S3 Object: lc-market-data:Futures/FR/EOP/CF/FRD_CFC1_2hour.txt
# Downloaded: lc-market-data:Futures/NZ/SFE/ZT/FRD_ZTC1_hour.txt
# 10000 frames added
# 17027 frames added
# Saved S3 Object: lc-market-data:Futures/NZ/SFE/ZT/FRD_ZTC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/OE/FRD_OEC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# Saved S3 Object: lc-market-data:Futures/DE/EUX/OE/FRD_OEC1_2hour.txt
# Downloaded: lc-market-data:Futures/DE/EUX/RX/FRD_RXC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# Saved S3 Object: lc-market-data:Futures/DE/EUX/RX/FRD_RXC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/EC/FRD_ECC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 47058 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/EC/FRD_ECC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/JY/FRD_JYC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/JY/FRD_JYC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/BP/FRD_BPC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 45686 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/BP/FRD_BPC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/AD/FRD_ADC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 46008 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/AD/FRD_ADC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/CD/FRD_CDC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/CD/FRD_CDC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/SF/FRD_SFC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 46155 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/SF/FRD_SFC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/NV/FRD_NVC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/NV/FRD_NVC1_2hour.txt
# Downloaded: lc-market-data:Futures/GB/ICF/L /FRD_L C1_hour.txt
# 10000 frames added
# 19309 frames added
# Saved S3 Object: lc-market-data:Futures/GB/ICF/L /FRD_L C1_2hour.txt
# Downloaded: lc-market-data:Futures/GB/ICF/G /FRD_G C1_hour.txt
# 10000 frames added
# 20000 frames added
# Saved S3 Object: lc-market-data:Futures/GB/ICF/G /FRD_G C1_2hour.txt
# Downloaded: lc-market-data:Futures/GB/ICF/ES/FRD_ESC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 40000 frames added
# 48543 frames added
# Saved S3 Object: lc-market-data:Futures/GB/ICF/ES/FRD_ESC1_2hour.txt
# Downloaded: lc-market-data:Futures/CH/EUX/SM/FRD_SMC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# 32634 frames added
# Saved S3 Object: lc-market-data:Futures/CH/EUX/SM/FRD_SMC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CBF/UX/FRD_UXC1_hour.txt
# 10000 frames added
# 20000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CBF/UX/FRD_UXC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/NYF/MES/FRD_MESC1_hour.txt
# 10000 frames added
# 20000 frames added
# Saved S3 Object: lc-market-data:Futures/US/NYF/MES/FRD_MESC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/BTC/FRD_BTCC1_hour.txt
# 10000 frames added
# 11293 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/BTC/FRD_BTCC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/FNX/DX/FRD_DXC1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# Saved S3 Object: lc-market-data:Futures/US/FNX/DX/FRD_DXC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_hour.txt
# 7257 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_hour.txt
# 7257 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME/C /FRD_C C1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME/C /FRD_C C1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME//FRD_C1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME//FRD_C1_2hour.txt
# Downloaded: lc-market-data:Futures/US/CME//FRD_C1_hour.txt
# 10000 frames added
# 20000 frames added
# 30000 frames added
# Saved S3 Object: lc-market-data:Futures/US/CME//FRD_C1_2hour.txt

# %%
cursor.execute("SELECT [HourRecordId], [DayRecordId] FROM dbo.FuturesStubs WHERE TTSymbol IS NOT NULL AND TTSymbol != ?", 'GC')
for row in cursor.fetchall():
    cursor.execute("SELECT [S3BucketName], [S3PathName], [S3FileName] FROM dbo.DataRecords WHERE Id = ?", row[0])
    for row_nest in cursor.fetchall():
        if check_if_s3_object_exists(row_nest[0], row_nest[1], 'FRD_'+row_nest[2]):
            df = get_s3_object(row_nest[0], row_nest[1], 'FRD_'+row_nest[2])
            cursor.execute("SELECT [S3BucketName], [S3PathName], [S3FileName] FROM dbo.DataRecords WHERE Id = ?", row[1])
            for row_nest2 in cursor.fetchall():
                if cursor.rowcount != 0:
                    save_s3_object(row_nest2[0], row_nest2[1], 'FRD_'+row_nest2[2], get_daily_bars(df))
# Out:
# Downloaded: lc-market-data:Futures/US/CME/ES/FRD_ESC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/ES/FRD_ESC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/NQ/FRD_NQC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/NQ/FRD_NQC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CBT/DM/FRD_DMC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/DM/FRD_DMC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/FA/FRD_FAC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/FA/FRD_FAC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/RTY/FRD_RTYC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/RTY/FRD_RTYC1_daily.txt
# Downloaded: lc-market-data:Futures/US/NYM/CL/FRD_CLC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/CL/FRD_CLC1_daily.txt
# Downloaded: lc-market-data:Futures/US/NYM/NG/FRD_NGC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/NG/FRD_NGC1_daily.txt
# Downloaded: lc-market-data:Futures/US/NYM/XB/FRD_XBC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/XB/FRD_XBC1_daily.txt
# Downloaded: lc-market-data:Futures/US/NYM/HO/FRD_HOC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/HO/FRD_HOC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CBT/FF/FRD_FFC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/FF/FRD_FFC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/ED/FRD_EDC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/ED/FRD_EDC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CBT/TU/FRD_TUC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/TU/FRD_TUC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CBT/TY/FRD_TYC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/TY/FRD_TYC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CBT/US/FRD_USC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBT/US/FRD_USC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CMX/HG/FRD_HGC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CMX/HG/FRD_HGC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CMX/SI/FRD_SIC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CMX/SI/FRD_SIC1_daily.txt
# Downloaded: lc-market-data:Futures/US/NYM/PL/FRD_PLC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/PL/FRD_PLC1_daily.txt
# Downloaded: lc-market-data:Futures/US/NYM/PA/FRD_PAC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYM/PA/FRD_PAC1_daily.txt
# Downloaded: lc-market-data:Futures/DE/EUX/GX/FRD_GXC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/GX/FRD_GXC1_daily.txt
# Downloaded: lc-market-data:Futures/DE/EUX/VG/FRD_VGC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/VG/FRD_VGC1_daily.txt
# Downloaded: lc-market-data:Futures/FR/EOP/CF/FRD_CFC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/FR/EOP/CF/FRD_CFC1_daily.txt
# Downloaded: lc-market-data:Futures/NZ/SFE/ZT/FRD_ZTC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/NZ/SFE/ZT/FRD_ZTC1_daily.txt
# Downloaded: lc-market-data:Futures/DE/EUX/OE/FRD_OEC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/OE/FRD_OEC1_daily.txt
# Downloaded: lc-market-data:Futures/DE/EUX/RX/FRD_RXC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/DE/EUX/RX/FRD_RXC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/EC/FRD_ECC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/EC/FRD_ECC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/JY/FRD_JYC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/JY/FRD_JYC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/BP/FRD_BPC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/BP/FRD_BPC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/AD/FRD_ADC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/AD/FRD_ADC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/CD/FRD_CDC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/CD/FRD_CDC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/SF/FRD_SFC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/SF/FRD_SFC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/NV/FRD_NVC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/NV/FRD_NVC1_daily.txt
# Downloaded: lc-market-data:Futures/GB/ICF/L /FRD_L C1_hour.txt
# Saved S3 Object: lc-market-data:Futures/GB/ICF/L /FRD_L C1_daily.txt
# Downloaded: lc-market-data:Futures/GB/ICF/G /FRD_G C1_hour.txt
# Saved S3 Object: lc-market-data:Futures/GB/ICF/G /FRD_G C1_daily.txt
# Downloaded: lc-market-data:Futures/GB/ICF/ES/FRD_ESC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/GB/ICF/ES/FRD_ESC1_daily.txt
# Downloaded: lc-market-data:Futures/CH/EUX/SM/FRD_SMC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/CH/EUX/SM/FRD_SMC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CBF/UX/FRD_UXC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CBF/UX/FRD_UXC1_daily.txt
# Downloaded: lc-market-data:Futures/US/NYF/MES/FRD_MESC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/NYF/MES/FRD_MESC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/BTC/FRD_BTCC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/BTC/FRD_BTCC1_daily.txt
# Downloaded: lc-market-data:Futures/US/FNX/DX/FRD_DXC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/FNX/DX/FRD_DXC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/HWA/FRD_HWAC1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME/C /FRD_C C1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/C /FRD_C C1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME//FRD_C1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME//FRD_C1_daily.txt
# Downloaded: lc-market-data:Futures/US/CME//FRD_C1_hour.txt
# Saved S3 Object: lc-market-data:Futures/US/CME/S /FRD_S C1_daily.txt
